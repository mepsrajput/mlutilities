# %%
# # data is refreshed daily.

# title.akas.tsv.gz - Contains the following information for titles:

# titleId (string) - a tconst, an alphanumeric unique identifier of the title
# ordering (integer) – a number to uniquely identify rows for a given titleId
# title (string) – the localized title
# region (string) - the region for this version of the title
# language (string) - the language of the title
# types (array) - Enumerated set of attributes for this alternative title. One or more of the following: "alternative", "dvd", "festival", "tv", "video", "working", "original", "imdbDisplay". New values may be added in the future without warning
# attributes (array) - Additional terms to describe this alternative title, not enumerated
# isOriginalTitle (boolean) – 0: not original title; 1: original title

# title.basics.tsv.gz - Contains the following information for titles:
# tconst (string) - alphanumeric unique identifier of the title
# titleType (string) – the type/format of the title (e.g. movie, short, tvseries, tvepisode, video, etc)
# primaryTitle (string) – the more popular title / the title used by the filmmakers on promotional materials at the point of release
# originalTitle (string) - original title, in the original language
# isAdult (boolean) - 0: non-adult title; 1: adult title
# startYear (YYYY) – represents the release year of a title. In the case of TV Series, it is the series start year
# endYear (YYYY) – TV Series end year. ‘\N’ for all other title types
# runtimeMinutes – primary runtime of the title, in minutes
# genres (string array) – includes up to three genres associated with the title

# title.crew.tsv.gz – Contains the director and writer information for all the titles in IMDb. Fields include:
# tconst (string) - alphanumeric unique identifier of the title
# directors (array of nconsts) - director(s) of the given title
# writers (array of nconsts) – writer(s) of the given title

# title.episode.tsv.gz – Contains the tv episode information. Fields include:
# tconst (string) - alphanumeric identifier of episode
# parentTconst (string) - alphanumeric identifier of the parent TV Series
# seasonNumber (integer) – season number the episode belongs to
# episodeNumber (integer) – episode number of the tconst in the TV series
# title.principals.tsv.gz – Contains the principal cast/crew for titles
# tconst (string) - alphanumeric unique identifier of the title
# ordering (integer) – a number to uniquely identify rows for a given titleId
# nconst (string) - alphanumeric unique identifier of the name/person
# category (string) - the category of job that person was in
# job (string) - the specific job title if applicable, else '\N'
# characters (string) - the name of the character played if applicable, else '\N'
# title.ratings.tsv.gz – Contains the IMDb rating and votes information for titles
# tconst (string) - alphanumeric unique identifier of the title
# averageRating – weighted average of all the individual user ratings
# numVotes - number of votes the title has received

# name.basics.tsv.gz – Contains the following information for names:
# nconst (string) - alphanumeric unique identifier of the name/person
# primaryName (string)– name by which the person is most often credited
# birthYear – in YYYY format
# deathYear – in YYYY format if applicable, else '\N'
# primaryProfession (array of strings)– the top-3 professions of the person
# knownForTitles (array of tconsts) – titles the person is known for

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://datasets.imdbws.com/'
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')

# %%
urls = []
for link in soup.find_all('a')[1:]:
    urls.append(link.get('href'))

# %%
for url in urls:
    
    df_suffix = url.split('/')[-1].split('.')[0] + '.' + url.split('/')[-1].split('.')[1]

    if df_suffix == 'name.basics':
        name_basics = pd.read_csv(url, compression='gzip', on_bad_lines='skip', sep='\t')
        print(name_basics.shape)
# Out:
# (12243512, 6)

# %%
# Split the columns having multiple values into multiple columns
name_basics[['primaryProfession1', 'primaryProfession2',  'primaryProfession3']] = name_basics['primaryProfession'].str.split(',', expand=True)

# %%
name_basics['famous_titles'] = name_basics['knownForTitles'].str.split(',')

# # Drop the not required columns
# name_basics.drop('primaryProfession', axis=1, inplace=True)
# name_basics.head()
# Out:
# 0    tt0050419,tt0053137,tt0045537,tt0072308
# Name: knownForTitles, dtype: object

# %%
name_basics[['famous_title1', 'famous_title2', 'famous_title3', 'famous_title4']] = name_basics['famous_titles'].apply(lambda x: pd.Series(str(x).split(",")))
name_basics.head()

# %% [markdown]
# ##### name_basics['knownForTitles'].str.split(',').len().max()

# %%
name_basics.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles primaryProfession1  \
# 0  tt0050419,tt0053137,tt0045537,tt0072308         soundtrack
# 1  tt0037382,tt0117057,tt0071877,tt0038355            actress
# 2  tt0056404,tt0054452,tt0049189,tt0057345            actress
# 3  tt0077975,tt0080455,tt0078723,tt0072562              actor
# 4  tt0050986,tt0060827,tt0083922,tt0050976             writer
#
#   primaryProfession2 primaryProfession3
# 0              actor      miscellaneous
# 1         soundtrack               None
# 2         soundtrack   music_department
# 3         soundtrack             writer
# 4           director              actor

# %%
name_basics.tail()
# Out:
#              nconst         primaryName birthYear deathYear  \
# 12243507  nm9993714   Romeo del Rosario        \N        \N
# 12243508  nm9993716       Essias Loberg        \N        \N
# 12243509  nm9993717  Harikrishnan Rajan        \N        \N
# 12243510  nm9993718         Aayush Nair        \N        \N
# 12243511  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 12243507  animation_department,art_department
# 12243508                                  NaN
# 12243509                      cinematographer
# 12243510                      cinematographer
# 12243511                                  NaN
#
#                            knownForTitles    primaryProfession1  \
# 12243507  tt2455546,tt14069590,tt11657662  animation_department
# 12243508                               \N                   NaN
# 12243509                        tt8736744       cinematographer
# 12243510                               \N       cinematographer
# 12243511                               \N                   NaN
#
#          primaryProfession2 primaryProfession3
# 12243507     art_department               None
# 12243508                NaN                NaN
# 12243509               None               None
# 12243510               None               None
# 12243511                NaN                NaN

# %%
name_basics.rename(columns = {'nconst':'name_const', 'primaryName': 'primary_name', 'birthYear': 'birth_year', deathYear: death_year, }, inplace = True)

# %%
name_basics.head(20)
# Out:
#        nconst          primaryName birthYear deathYear  \
# 0   nm0000001         Fred Astaire      1899      1987
# 1   nm0000002        Lauren Bacall      1924      2014
# 2   nm0000003      Brigitte Bardot      1934        \N
# 3   nm0000004         John Belushi      1949      1982
# 4   nm0000005       Ingmar Bergman      1918      2007
# 5   nm0000006       Ingrid Bergman      1915      1982
# 6   nm0000007      Humphrey Bogart      1899      1957
# 7   nm0000008        Marlon Brando      1924      2004
# 8   nm0000009       Richard Burton      1925      1984
# 9   nm0000010         James Cagney      1899      1986
# 10  nm0000011          Gary Cooper      1901      1961
# 11  nm0000012          Bette Davis      1908      1989
# 12  nm0000013            Doris Day      1922      2019
# 13  nm0000014  Olivia de Havilland      1916      2020
# 14  nm0000015           James Dean      1931      1955
# 15  nm0000016      Georges Delerue      1925      1992
# 16  nm0000017     Marlene Dietrich      1901      1992
# 17  nm0000018         Kirk Douglas      1916      2020
# 18  nm0000019     Federico Fellini      1920      1993
# 19  nm0000020          Henry Fonda      1905      1982
#
#                         primaryProfession  \
# 0          soundtrack,actor,miscellaneous
# 1                      actress,soundtrack
# 2     actress,soundtrack,music_department
# 3                 actor,soundtrack,writer
# 4                   writer,director,actor
# 5             actress,soundtrack,producer
# 6               actor,soundtrack,producer
# 7               actor,soundtrack,director
# 8               actor,soundtrack,producer
# 9               actor,soundtrack,director
# 10                actor,soundtrack,stunts
# 11  actress,soundtrack,make_up_department
# 12            soundtrack,actress,producer
# 13                     actress,soundtrack
# 14                    actor,miscellaneous
# 15   composer,soundtrack,music_department
# 16    soundtrack,actress,music_department
# 17              actor,producer,soundtrack
# 18                  writer,director,actor
# 19              actor,producer,soundtrack
#
#                              knownForTitles primaryProfession1  \
# 0   tt0050419,tt0053137,tt0045537,tt0072308         soundtrack
# 1   tt0037382,tt0117057,tt0071877,tt0038355            actress
# 2   tt0056404,tt0054452,tt0049189,tt0057345            actress
# 3   tt0077975,tt0080455,tt0078723,tt0072562              actor
# 4   tt0050986,tt0060827,tt0083922,tt0050976             writer
# 5   tt0036855,tt0038787,tt0038109,tt0034583            actress
# 6   tt0042593,tt0037382,tt0034583,tt0043265              actor
# 7   tt0070849,tt0068646,tt0078788,tt0047296              actor
# 8   tt0061184,tt0087803,tt0057877,tt0059749              actor
# 9   tt0042041,tt0029870,tt0031867,tt0035575              actor
# 10  tt0034167,tt0027996,tt0044706,tt0035896              actor
# 11  tt0035140,tt0031210,tt0056687,tt0042192            actress
# 12  tt0048317,tt0049470,tt0053172,tt0045591         soundtrack
# 13  tt0031381,tt0029843,tt0040806,tt0041452            actress
# 14  tt0049261,tt0048545,tt0048028,tt0039123              actor
# 15  tt0069946,tt0091763,tt8847712,tt0096320           composer
# 16  tt0021156,tt0051201,tt0055031,tt0052311         soundtrack
# 17  tt0050825,tt0054331,tt0043338,tt0049456              actor
# 18  tt0050783,tt0053779,tt0071129,tt0056801             writer
# 19  tt0050083,tt0051207,tt0032551,tt0082846              actor
#
#    primaryProfession2  primaryProfession3
# 0               actor       miscellaneous
# 1          soundtrack                None
# 2          soundtrack    music_department
# 3          soundtrack              writer
# 4            director               actor
# 5          soundtrack            producer
# 6          soundtrack            producer
# 7          soundtrack            director
# 8          soundtrack            producer
# 9          soundtrack            director
# 10         soundtrack              stunts
# 11         soundtrack  make_up_department
# 12            actress            producer
# 13         soundtrack                None
# 14      miscellaneous                None
# 15         soundtrack    music_department
# 16            actress    music_department
# 17           producer          soundtrack
# 18           director               actor
# 19           producer          soundtrack
